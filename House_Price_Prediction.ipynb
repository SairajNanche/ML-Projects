# %% [markdown]
# ###Name : Sairaj Nanche
# ### Roll no : 21102B0006
# ### Git :[https://github.com/SairajNanche/ML-Projects.git](https://github.com/SairajNanche/ML-Projects.git)

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from seaborn import heatmap
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
data = pd.read_csv('/content/housing.csv')

# %%
print(data.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data=data.dropna()

# %%
data.drop('ocean_proximity',axis=1, inplace=True)
x=data.drop('median_house_value',axis=1)
y=data['median_house_value']

# %%
plt,ax=plt.subplots(figsize=(10,8))
heatmap(data.corr(),annot=True,ax=ax)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=1)

# %%
scaler = StandardScaler()
X_train= scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(f"Predicted values: {y_pred}")
print(f"Actual values: {y_test}")
# Out:
# Predicted values: [377391.41409712 274015.85270734 147032.98093884 ... 134782.92330105
#  428717.35100962 274864.76957775]
# Actual values: 6715     360900.0
# 4121     291500.0
# 15433    131300.0
# 20272    500001.0
# 11843    118800.0
#            ...
# 6679     242400.0
# 9862     218000.0
# 9456      69800.0
# 17145    500001.0
# 3968     220200.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Error:", mae)
print("r2 score:", r2)
# Out:
# Mean Squared Error: 4716012366.647063
# Root Mean Squared Error: 68673.22889341277
# Mean Absolute Error: 50254.722735952135
# r2 score: 0.645328950325208

# %%
accuracy=model.score(X_test,y_test)
print(accuracy)
# Out:
# 0.645328950325208
